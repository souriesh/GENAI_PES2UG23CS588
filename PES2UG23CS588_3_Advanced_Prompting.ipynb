# %%
# Setup
# %pip install python-dotenv --upgrade --quiet langchain langchain-groq

from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_groq import ChatGroq

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API Key: ")

# Using Llama3.1-8b (Small/Fast) to demonstrate logic failures
llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.0)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 1.3 MB/s eta 0:00:00
# Enter your Groq API Key: ··········

# %%
question = "Roger has 5 tennis balls. He buys 2 more cans of tennis balls. Each can has 3 tennis balls. How many does he have now?"

# 1. Standard Prompt (Direct Answer)
prompt_standard = f"Answer this question: {question}"
print("--- STANDARD (Llama3.1-8b) ---")
print(llm.invoke(prompt_standard).content)
# Out:
# --- STANDARD (Llama3.1-8b) ---
# To find out how many tennis balls Roger has now, we need to add the initial number of tennis balls he had (5) to the number of tennis balls he bought (2 cans * 3 tennis balls per can).
#
# 2 cans * 3 tennis balls per can = 6 tennis balls
#
# Now, let's add the initial number of tennis balls (5) to the number of tennis balls he bought (6):
#
# 5 + 6 = 11
#
# So, Roger now has 11 tennis balls.

# %%
# 2. CoT Prompt (Magic Phrase)
prompt_cot = f"Answer this question. Let's think step by step. {question}"

print("--- Chain of Thought (Llama3.1-8b) ---")
print(llm.invoke(prompt_cot).content)
# Out:
# --- Chain of Thought (Llama3.1-8b) ---
# To find out how many tennis balls Roger has now, we need to follow these steps:
#
# 1. Roger already has 5 tennis balls.
# 2. He buys 2 more cans of tennis balls. Each can has 3 tennis balls, so he buys 2 x 3 = 6 more tennis balls.
# 3. Now, we add the tennis balls he already had (5) to the new tennis balls he bought (6). 5 + 6 = 11
#
# So, Roger now has 11 tennis balls.

# %%
# Setup
# %pip install python-dotenv --upgrade --quiet langchain langchain-groq

from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_groq import ChatGroq

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API Key: ")

# Using Llama3.1-8b
llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.7) # Creativity needed

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

problem = "How can I get my 5-year-old to eat vegetables?"

# Step 1: The Branch Generator
prompt_branch = ChatPromptTemplate.from_template(
    "Problem: {problem}. Give me one unique, creative solution. Solution {id}:"
)

branches = RunnableParallel(
    sol1=prompt_branch.partial(id="1") | llm | StrOutputParser(),
    sol2=prompt_branch.partial(id="2") | llm | StrOutputParser(),
    sol3=prompt_branch.partial(id="3") | llm | StrOutputParser(),
)

# Step 2: The Judge
prompt_judge = ChatPromptTemplate.from_template(
    """
    I have three proposed solutions for: '{problem}'

    1: {sol1}
    2: {sol2}
    3: {sol3}

    Act as a Child Psychologist. Pick the most sustainable one (not bribery) and explain why.
    """
)

# Chain: Input -> Branches -> Judge -> Output
tot_chain = (
    RunnableParallel(problem=RunnableLambda(lambda x: x), branches=branches)
    | (lambda x: {**x["branches"], "problem": x["problem"]})
    | prompt_judge
    | llm
    | StrOutputParser()
)

print("--- Tree of Thoughts (ToT) Result ---")
print(tot_chain.invoke(problem))
# Out:
# --- Tree of Thoughts (ToT) Result ---
# As a child psychologist, I highly recommend Solution 3: "Garden in a Jar" experience at home. This approach is not only creative and engaging, but it also fosters a sense of responsibility, creativity, and emotional connection with the vegetables. Here's why I think it's the most sustainable solution:
#
# 1. **Emotional Connection**: By creating a story and imagining characters in the garden, your child develops an emotional connection with the vegetables. This emotional investment can motivate them to try new vegetables and enjoy them.
# 2. **Responsibility**: Letting your child help with the planting process and caring for the garden in a jar teaches them responsibility and a sense of ownership. They'll be more invested in the outcome and more likely to try the vegetables that grow.
# 3. **Creativity**: The "Garden in a Jar" experience encourages creativity and imagination. Your child will enjoy creating a story and character for the garden, which can lead to a more positive association with vegetables.
# 4. **Learning Experience**: This approach combines education and fun. Your child will learn about different types of vegetables, their growth cycle, and how to care for them.
# 5. **Long-term Benefits**: The "Garden in a Jar" experience can lead to long-term benefits, such as a more adventurous palate, a willingness to try new foods, and a healthier relationship with food.
#
# In contrast, the other two solutions, while creative and engaging, have some limitations:
#
# * Solution 1: "Fruit and Veggie Face" might be seen as a one-time trick, and children may become bored with it over time.
# * Solution 2: "Make Your Own Pizza" with hidden veggies can be seen as a form of sneaking vegetables, which may not be effective in the long run. Children may become aware of the hidden veggies and resist trying them.
#
# In contrast, the "Garden in a Jar" experience is a more sustainable and long-term approach that encourages creativity, responsibility, and emotional connection with vegetables. As a child psychologist, I recommend this approach as a effective and engaging way to encourage healthy eating habits in children.

# %%
# 1. The Generator (Divergence)
prompt_draft = ChatPromptTemplate.from_template(
    "Write a 1-sentence movie plot about: {topic}. Genre: {genre}."
)

drafts = RunnableParallel(
    draft_scifi=prompt_draft.partial(genre="Sci-Fi") | llm | StrOutputParser(),
    draft_romance=prompt_draft.partial(genre="Romance") | llm | StrOutputParser(),
    draft_horror=prompt_draft.partial(genre="Horror") | llm | StrOutputParser(),
)

# 2. The Aggregator (Convergence)
prompt_combine = ChatPromptTemplate.from_template(
    """
    I have three movie ideas for the topic '{topic}':
    1. Sci-Fi: {draft_scifi}
    2. Romance: {draft_romance}
    3. Horror: {draft_horror}

    Your task: Create a new Mega-Movie that combines the TECHNOLOGY of Sci-Fi, the PASSION of Romance, and the FEAR of Horror.
    Write one paragraph.
    """
)

# 3. The Chain
got_chain = (
    RunnableParallel(topic=RunnableLambda(lambda x: x), drafts=drafts)
    | (lambda x: {**x["drafts"], "topic": x["topic"]})
    | prompt_combine
    | llm
    | StrOutputParser()
)

print("--- Graph of Thoughts (GoT) Result ---")
print(got_chain.invoke("Time Travel"))
# Out:
# --- Graph of Thoughts (GoT) Result ---
# "In 'Echoes of Eternity,' a brilliant and reclusive physicist, Emma, discovers a way to manipulate time using an innovative technology that allows her to create echoes of her past self, each inhabiting a parallel universe. As she uses this technology to relive her past and reunite with her former fiancé, Jack, who died in a tragic accident five years prior, she becomes trapped in a never-ending cycle of timelines. Her repeated attempts to alter the course of events to save Jack create multiple echoes of herself, each with their own agendas and desires, but they also awaken a dark presence that haunts the timelines, threatening to destroy the fabric of reality. As Emma navigates the blurring lines between love, loss, and time, she must confront the ultimate question: can she find a way to save Jack, or will her attempts to alter the past forever seal their doom?"
